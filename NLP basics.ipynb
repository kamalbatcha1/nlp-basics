# %%
import nltk

# %%
dir(nltk)
# Out:
# ['ARLSTem',
#  'ARLSTem2',
#  'AbstractLazySequence',
#  'AffixTagger',
#  'AlignedSent',
#  'Alignment',
#  'AnnotationTask',
#  'ApplicationExpression',
#  'Assignment',
#  'BigramAssocMeasures',
#  'BigramCollocationFinder',
#  'BigramTagger',
#  'BinaryMaxentFeatureEncoding',
#  'BlanklineTokenizer',
#  'BllipParser',
#  'BottomUpChartParser',
#  'BottomUpLeftCornerChartParser',
#  'BottomUpProbabilisticChartParser',
#  'Boxer',
#  'BrillTagger',
#  'BrillTaggerTrainer',
#  'CFG',
#  'CRFTagger',
#  'CfgReadingCommand',
#  'ChartParser',
#  'ChunkParserI',
#  'ChunkScore',
#  'Cistem',
#  'ClassifierBasedPOSTagger',
#  'ClassifierBasedTagger',
#  'ClassifierI',
#  'ConcordanceIndex',
#  'ConditionalExponentialClassifier',
#  'ConditionalFreqDist',
#  'ConditionalProbDist',
#  'ConditionalProbDistI',
#  'ConfusionMatrix',
#  'ContextIndex',
#  'ContextTagger',
#  'ContingencyMeasures',
#  'CoreNLPDependencyParser',
#  'CoreNLPParser',
#  'Counter',
#  'CrossValidationProbDist',
# ...

# %%
from nltk.corpus import stopwords
stopwords.words("english")
# Out:
# ['i',
#  'me',
#  'my',
#  'myself',
#  'we',
#  'our',
#  'ours',
#  'ourselves',
#  'you',
#  "you're",
#  "you've",
#  "you'll",
#  "you'd",
#  'your',
#  'yours',
#  'yourself',
#  'yourselves',
#  'he',
#  'him',
#  'his',
#  'himself',
#  'she',
#  "she's",
#  'her',
#  'hers',
#  'herself',
#  'it',
#  "it's",
#  'its',
#  'itself',
#  'they',
#  'them',
#  'their',
#  'theirs',
#  'themselves',
#  'what',
#  'which',
#  'who',
#  'whom',
#  'this',
#  'that',
#  "that'll",
#  'these',
#  'those',
#  'am',
#  'is',
#  'are',
#  'was',
#  'were',
#  'be',
#  'been',
#  'being',
#  'have',
#  'has',
#  'had',
#  'having',
#  'do',
#  'does',
#  'did',
#  'doing',
#  'a',
#  'an',
#  'the',
#  'and',
#  'but',
#  'if',
#  'or',
#  'because',
#  'as',
#  'until',
#  'while',
#  'of',
#  'at',
#  'by',
#  'for',
#  'with',
#  'about',
#  'against',
#  'between',
#  'into',
#  'through',
#  'during',
#  'before',
#  'after',
#  'above',
#  'below',
#  'to',
#  'from',
#  'up',
# ...

# %%
rawData=open("Ch01/01_03/Start/SMSSpamCollection.tsv").read()
rawData[0:500]
# Out:
# "ham\tI've been searching for the right words to thank you for this breather. I promise i wont take your help for granted and will fulfil my promise. You have been wonderful and a blessing at all times.\nspam\tFree entry in 2 a wkly comp to win FA Cup final tkts 21st May 2005. Text FA to 87121 to receive entry question(std txt rate)T&C's apply 08452810075over18's\nham\tNah I don't think he goes to usf, he lives around here though\nham\tEven my brother is not like to speak with me. They treat me like aid"

# %%
parsedData=rawData.replace("\t","\n").split("\n")

# %%
parsedData[0:5]
# Out:
# ['ham',
#  "I've been searching for the right words to thank you for this breather. I promise i wont take your help for granted and will fulfil my promise. You have been wonderful and a blessing at all times.",
#  'spam',
#  "Free entry in 2 a wkly comp to win FA Cup final tkts 21st May 2005. Text FA to 87121 to receive entry question(std txt rate)T&C's apply 08452810075over18's",
#  'ham']

# %%
LabelList=parsedData[0::2]
textList=parsedData[1::2]

# %%
print(LabelList[0:5])
print(textList[0:5])
# Out:
# ['ham', 'spam', 'ham', 'ham', 'ham']
# ["I've been searching for the right words to thank you for this breather. I promise i wont take your help for granted and will fulfil my promise. You have been wonderful and a blessing at all times.", "Free entry in 2 a wkly comp to win FA Cup final tkts 21st May 2005. Text FA to 87121 to receive entry question(std txt rate)T&C's apply 08452810075over18's", "Nah I don't think he goes to usf, he lives around here though", 'Even my brother is not like to speak with me. They treat me like aids patent.', 'I HAVE A DATE ON SUNDAY WITH WILL!!']

# %%
import pandas as pd

# %%
print(len(LabelList))
print(len(textList))
# Out:
# 5571
# 5570

# %%
print(LabelList[-5:])
# Out:
# ['ham', 'ham', 'ham', 'ham', '']

# %%
fullCorpus=pd.DataFrame({
    "label":LabelList[:-1],
    "body_list":textList
})
fullCorpus.head()
# Out:
#   label  \
# 0   ham
# 1  spam
# 2   ham
# 3   ham
# 4   ham
#
#                                                                                              body_list
# 0  I've been searching for the right words to thank you for this breather. I promise i wont take yo...
# 1  Free entry in 2 a wkly comp to win FA Cup final tkts 21st May 2005. Text FA to 87121 to receive ...
# 2                                        Nah I don't think he goes to usf, he lives around here though
# 3                        Even my brother is not like to speak with me. They treat me like aids patent.
# 4                                                                  I HAVE A DATE ON SUNDAY WITH WILL!!

# %%
fullCorpus=pd.read_csv("Ch01/01_03/Start/SMSSpamCollection.tsv",sep="\t",header=None)
fullCorpus.columns=("label","body_list")

# %%
fullCorpus.head()
# Out:
#   label  \
# 0   ham
# 1  spam
# 2   ham
# 3   ham
# 4   ham
#
#                                                                                              body_list
# 0  I've been searching for the right words to thank you for this breather. I promise i wont take yo...
# 1  Free entry in 2 a wkly comp to win FA Cup final tkts 21st May 2005. Text FA to 87121 to receive ...
# 2                                        Nah I don't think he goes to usf, he lives around here though
# 3                        Even my brother is not like to speak with me. They treat me like aids patent.
# 4                                                                  I HAVE A DATE ON SUNDAY WITH WILL!!

# %%
#shape
print("Input data has {} rows and {} columns".format(len(fullCorpus),len(fullCorpus.columns)))
# Out:
# Input data has 5568 rows and 2 columns

# %%
#how many spam
print("out of {} rows {} are spams {} are ham".format(len(fullCorpus),len(fullCorpus[fullCorpus["label"]=="spam"]),len(fullCorpus[fullCorpus["label"]=="ham"])))
# Out:
# out of 5568 rows 746 are spams 4822 are ham

# %%
fullCorpus.isnull().sum()
# Out:
# label        0
# body_list    0
# dtype: int64

# %% [markdown]
# Regular Expression:

# %%
import re
re_test = 'This is a made up string to test 2 different regex methods'
re_test_messy = 'This      is a made up     string to test 2    different regex methods'
re_test_messy1 = 'This-is-a-made/up.string*to>>>>test----2""""""different~regex-methods'

# %%
re.split("\s",re_test)
# Out:
# ['This',
#  'is',
#  'a',
#  'made',
#  'up',
#  'string',
#  'to',
#  'test',
#  '2',
#  'different',
#  'regex',
#  'methods']

# %%
re.split("\s",re_test_messy)
# Out:
# ['This',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'is',
#  'a',
#  'made',
#  'up',
#  '',
#  '',
#  '',
#  '',
#  'string',
#  'to',
#  'test',
#  '2',
#  '',
#  '',
#  '',
#  'different',
#  'regex',
#  'methods']

# %%
re.split("\s+",re_test_messy)
# Out:
# ['This',
#  'is',
#  'a',
#  'made',
#  'up',
#  'string',
#  'to',
#  'test',
#  '2',
#  'different',
#  'regex',
#  'methods']

# %%
re.split("\W+",re_test_messy)
# Out:
# ['This',
#  'is',
#  'a',
#  'made',
#  'up',
#  'string',
#  'to',
#  'test',
#  '2',
#  'different',
#  'regex',
#  'methods']

# %%
re.findall("\S+",re_test)
# Out:
# ['This',
#  'is',
#  'a',
#  'made',
#  'up',
#  'string',
#  'to',
#  'test',
#  '2',
#  'different',
#  'regex',
#  'methods']

# %%
re.findall("\S+",re_test_messy)
# Out:
# ['This',
#  'is',
#  'a',
#  'made',
#  'up',
#  'string',
#  'to',
#  'test',
#  '2',
#  'different',
#  'regex',
#  'methods']

# %%
re.findall("\S+",re_test_messy1)
# Out:
# ['This-is-a-made/up.string*to>>>>test----2""""""different~regex-methods']

# %%
re.findall("\w+",re_test_messy1)
# Out:
# ['This',
#  'is',
#  'a',
#  'made',
#  'up',
#  'string',
#  'to',
#  'test',
#  '2',
#  'different',
#  'regex',
#  'methods']

# %% [markdown]
# Replacing a Specific String

# %%
pep8_test = 'I try to follow PEP8 guidelines'
pep7_test = 'I try to follow PEP7 guidelines'
peep8_test = 'I try to follow PEEP8 guidelines'

# %%
re.findall("[a-z]+",pep8_test)
# Out:
# ['try', 'to', 'follow', 'guidelines']

# %%
re.findall("[A-Z]+",pep8_test)
# Out:
# ['I', 'PEP']

# %%
re.findall("[A-Z0-9]+",pep8_test)
# Out:
# ['I', 'PEP8']

# %%
re.findall("[A-Z]+[0-9]+",peep8_test)
# Out:
# ['PEEP8']

# %%
re.sub("[A-Z]+[0-9]+","PEP8 Python Styleguide",peep8_test)
# Out:
# 'I try to follow PEP8 Python Styleguide guidelines'

# %%
import pandas as pd
pd.set_option("display.max_colwidth",100)
data=pd.read_csv("Ch01/01_11/End/SMSSpamCollection.tsv",sep="\t",header=None)
data.columns=["label","body_text"]

# %%
data.head()
# Out:
#   label  \
# 0   ham
# 1  spam
# 2   ham
# 3   ham
# 4   ham
#
#                                                                                              body_text
# 0  I've been searching for the right words to thank you for this breather. I promise i wont take yo...
# 1  Free entry in 2 a wkly comp to win FA Cup final tkts 21st May 2005. Text FA to 87121 to receive ...
# 2                                        Nah I don't think he goes to usf, he lives around here though
# 3                        Even my brother is not like to speak with me. They treat me like aids patent.
# 4                                                                  I HAVE A DATE ON SUNDAY WITH WILL!!

# %%
data_cleaned=pd.read_csv("Ch01/01_11/End/SMSSpamCollection_cleaned.tsv",sep="\t")
data_cleaned.head()
# Out:
#   label  \
# 0   ham
# 1  spam
# 2   ham
# 3   ham
# 4   ham
#
#                                                                                              body_text  \
# 0  I've been searching for the right words to thank you for this breather. I promise i wont take yo...
# 1  Free entry in 2 a wkly comp to win FA Cup final tkts 21st May 2005. Text FA to 87121 to receive ...
# 2                                        Nah I don't think he goes to usf, he lives around here though
# 3                        Even my brother is not like to speak with me. They treat me like aids patent.
# 4                                                                  I HAVE A DATE ON SUNDAY WITH WILL!!
#
#                                                                                       body_text_nostop
# 0  ['ive', 'searching', 'right', 'words', 'thank', 'breather', 'promise', 'wont', 'take', 'help', '...
# ...

# %% [markdown]
# Remove Punctuation

# %%
import string
string.punctuation
# Out:
# '!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~'

# %%
"I like NLP."=="I like NLP"
# Out:
# False

# %%
def remove_punct(text):
    text_nopunct = "".join([char for char in text if char not in string.punctuation])
    return text_nopunct

data['body_text_clean'] = data['body_text'].apply(lambda x: remove_punct(x))

data.head()
# Out:
#   label  \
# 0   ham
# 1  spam
# 2   ham
# 3   ham
# 4   ham
#
#                                                                                              body_text  \
# 0  I've been searching for the right words to thank you for this breather. I promise i wont take yo...
# 1  Free entry in 2 a wkly comp to win FA Cup final tkts 21st May 2005. Text FA to 87121 to receive ...
# 2                                        Nah I don't think he goes to usf, he lives around here though
# 3                        Even my brother is not like to speak with me. They treat me like aids patent.
# 4                                                                  I HAVE A DATE ON SUNDAY WITH WILL!!
#
#                                                                                        body_text_clean
# 0  Ive been searching for the right words to thank you for this breather I promise i wont take your...
# ...

# %% [markdown]
# Tokenization

# %%
def tokenize(text):
    tokens = re.split('\W+', text)
    return tokens

data['body_text_tokenized'] = data['body_text_clean'].apply(lambda x: tokenize(x.lower()))

data.head()
# Out:
#   label  \
# 0   ham
# 1  spam
# 2   ham
# 3   ham
# 4   ham
#
#                                                                                              body_text  \
# 0  I've been searching for the right words to thank you for this breather. I promise i wont take yo...
# 1  Free entry in 2 a wkly comp to win FA Cup final tkts 21st May 2005. Text FA to 87121 to receive ...
# 2                                        Nah I don't think he goes to usf, he lives around here though
# 3                        Even my brother is not like to speak with me. They treat me like aids patent.
# 4                                                                  I HAVE A DATE ON SUNDAY WITH WILL!!
#
#                                                                                        body_text_clean  \
# 0  Ive been searching for the right words to thank you for this breather I promise i wont take your...
# ...

# %% [markdown]
# Remove StopWords

# %%
stopword=nltk.corpus.stopwords.words("english")
stopword
# Out:
# ['i',
#  'me',
#  'my',
#  'myself',
#  'we',
#  'our',
#  'ours',
#  'ourselves',
#  'you',
#  "you're",
#  "you've",
#  "you'll",
#  "you'd",
#  'your',
#  'yours',
#  'yourself',
#  'yourselves',
#  'he',
#  'him',
#  'his',
#  'himself',
#  'she',
#  "she's",
#  'her',
#  'hers',
#  'herself',
#  'it',
#  "it's",
#  'its',
#  'itself',
#  'they',
#  'them',
#  'their',
#  'theirs',
#  'themselves',
#  'what',
#  'which',
#  'who',
#  'whom',
#  'this',
#  'that',
#  "that'll",
#  'these',
#  'those',
#  'am',
#  'is',
#  'are',
#  'was',
#  'were',
#  'be',
#  'been',
#  'being',
#  'have',
#  'has',
#  'had',
#  'having',
#  'do',
#  'does',
#  'did',
#  'doing',
#  'a',
#  'an',
#  'the',
#  'and',
#  'but',
#  'if',
#  'or',
#  'because',
#  'as',
#  'until',
#  'while',
#  'of',
#  'at',
#  'by',
#  'for',
#  'with',
#  'about',
#  'against',
#  'between',
#  'into',
#  'through',
#  'during',
#  'before',
#  'after',
#  'above',
#  'below',
#  'to',
#  'from',
#  'up',
# ...

# %%
def remove_stopwords(tokenized_list):
    text = [word for word in tokenized_list if word not in stopword]
    return text

data['body_text_nostop'] = data['body_text_tokenized'].apply(lambda x: remove_stopwords(x))

data.head()
# Out:
#   label  \
# 0   ham
# 1  spam
# 2   ham
# 3   ham
# 4   ham
#
#                                                                                              body_text  \
# 0  I've been searching for the right words to thank you for this breather. I promise i wont take yo...
# 1  Free entry in 2 a wkly comp to win FA Cup final tkts 21st May 2005. Text FA to 87121 to receive ...
# 2                                        Nah I don't think he goes to usf, he lives around here though
# 3                        Even my brother is not like to speak with me. They treat me like aids patent.
# 4                                                                  I HAVE A DATE ON SUNDAY WITH WILL!!
#
#                                                                                        body_text_clean  \
# 0  Ive been searching for the right words to thank you for this breather I promise i wont take your...
# ...

# %%
re.split('\s',"This is an interesting te+st")
# Out:
# ['This', 'is', 'an', 'interesting', 'te+st']
